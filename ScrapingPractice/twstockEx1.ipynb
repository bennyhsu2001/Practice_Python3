# %%
import twstock

stockid='2317'
stock = twstock.Stock(stockid)
stock = stock.fetch_from(2017,5)
print('2017-05 to now %s stock price:\n'%stockid,stock.price)

real = twstock.realtime.get(stockid)
prinr(real)
if real['success']: print('real-time stock data:\n',real)
else: print('Error:',real['rtmessage'])
print('real-time stock price:',real['realtime']['latest_trade_price'])
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# c:\users\student\appdata\local\programs\python\python36-32\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     170             conn = connection.create_connection(
# --> 171                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     172
#
# c:\users\student\appdata\local\programs\python\python36-32\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      78     if err is not None:
# ---> 79         raise err
#      80
#
# c:\users\student\appdata\local\programs\python\python36-32\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      68                 sock.bind(source_address)
# ---> 69             sock.connect(sa)
#      70             return sock
#
# ...
