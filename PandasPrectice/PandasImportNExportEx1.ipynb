# %%
import pandas as pd
# import numpy as np

# %%
data=pd.read_csv('EF05M01.csv')
print(data)
# Out:
#           期間 短期票券市場-當期交易金額-原始值 股票市場-總市值-原始值 股票市場-當期成交金額-原始值
# 0    1961M07                 -            -               -
# 1    1961M08                 -            -               -
# 2    1961M09                 -            -               -
# 3    1961M10                 -            -               -
# 4    1961M11                 -            -               -
# 5    1961M12                 -            -               -
# 6    1962M01                 -            -               -
# 7    1962M02                 -            -               -
# 8    1962M03                 -            -               1
# 9    1962M04                 -            -               1
# 10   1962M05                 -            -               1
# 11   1962M06                 -            -               1
# 12   1962M07                 -            -               -
# 13   1962M08                 -            -               -
# 14   1962M09                 -            -               -
# ...

# %%
data.to_pickle('EF05M01.pickle')
